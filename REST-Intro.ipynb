# %% [markdown]
# # Resource and URL Patterns

# %% [markdown]
# ## Simple Data and Resource Model

# %% [markdown]
# | ![image.png](attachment:image.png) |
# | :---: |
# | Simple ER Diagram |

# %% [markdown]
# ## Connect to Service in a "Pythonic-Way"

# %%
#
# A Python package that encapsulates SQL. Somewhat analogous to our initial, "low level" PyAnsys APIs.
#
import pymysql

# %%
# 
# This is a magic and an example of higher layer, simplifying abstractions.
#
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
#
# Connect to a "service"
#
# %sql mysql+pymysql://dbuser:dbuserdbuser@localhost

# %%
#
# Let's look at what the tables are.
#
# %sql use lahmansdb;
# Out:
#  * mysql+pymysql://dbuser:***@localhost
# 0 rows affected.
# []

# %%
# %sql show tables;
# Out:
#  * mysql+pymysql://dbuser:***@localhost
# 7 rows affected.
# [('appearances',),
#  ('appearances_fast',),
#  ('appearances_fixed',),
#  ('Batting',),
#  ('people',),
#  ('people_fast',),
#  ('teams',)]

# %% [markdown]
# ## Some Examples

# %% [markdown]
# - Find a specific person. The URL path would be ```/people/willite01```
#
#
# - The corresponding SQL query to understand the concept is ... ...

# %%
# %sql select * from people where playerid='willite01'
# Out:
#  * mysql+pymysql://dbuser:***@localhost
# 1 rows affected.
# [('willite01', 1918.0, 8.0, 30.0, 'USA', 'CA', 'San Diego', 2002.0, 7.0, 5.0, 'USA', 'FL', 'Inverness', 'Ted', 'Williams', 'Theodore Samuel', 205.0, 75.0, 'L', 'R', '1939-04-20', '1960-09-28', 'willt103', 'willite01')]

# %% [markdown]
# - Find all people that match a pattern. The URL would be ```people?birthCity=San Diego&nameLast=Williams```
#
#
# - The corresponding SQL query would be ... ...

# %%
# %sql select * from people where birthCity='San Diego' and nameLast='Williams'
# Out:
#  * mysql+pymysql://dbuser:***@localhost
# 2 rows affected.
# [('willite01', 1918.0, 8.0, 30.0, 'USA', 'CA', 'San Diego', 2002.0, 7.0, 5.0, 'USA', 'FL', 'Inverness', 'Ted', 'Williams', 'Theodore Samuel', 205.0, 75.0, 'L', 'R', '1939-04-20', '1960-09-28', 'willt103', 'willite01'),
#  ('willitr01', 1992.0, 4.0, 25.0, 'USA', 'CA', 'San Diego', None, None, None, None, None, None, 'Trevor', 'Williams', 'Trevor Anthony', 235.0, 75.0, 'R', 'R', '2016-09-07', '2021-10-03', 'willt002', 'willitr01')]

# %% [markdown]
# - Follow a "relationship" to find a player's batting information. The URL would be ```/people/willite01/batting.```
#
#
# - The underlying SQL query would be something like ... ...

# %%
# %%sql
#
# select * from batting where batting.playerID='willite01'
# Out:
#  * mysql+pymysql://dbuser:***@localhost
# 19 rows affected.
# [('willite01', 1939, 1, 'BOS', 'AL', 149, 565, 131, 185, 44, 11, 31, 145, 2, 1, 107, 64, None, '2', '3', None, 10),
#  ('willite01', 1940, 1, 'BOS', 'AL', 144, 561, 134, 193, 43, 14, 23, 113, 4, 4, 96, 54, None, '3', '1', None, 13),
#  ('willite01', 1941, 1, 'BOS', 'AL', 143, 456, 135, 185, 33, 3, 37, 120, 2, 4, 147, 27, None, '3', '0', None, 10),
#  ('willite01', 1942, 1, 'BOS', 'AL', 150, 522, 141, 186, 34, 5, 36, 137, 3, 2, 145, 51, None, '4', '0', None, 12),
#  ('willite01', 1946, 1, 'BOS', 'AL', 150, 514, 142, 176, 37, 8, 38, 123, 0, 0, 156, 44, None, '2', '0', None, 12),
#  ('willite01', 1947, 1, 'BOS', 'AL', 156, 528, 125, 181, 40, 9, 32, 114, 0, 1, 162, 47, None, '2', '1', None, 10),
#  ('willite01', 1948, 1, 'BOS', 'AL', 137, 509, 124, 188, 44, 3, 25, 127, 4, 0, 126, 41, None, '3', '0', None, 10),
#  ('willite01', 1949, 1, 'BOS', 'AL', 155, 566, 150, 194, 39, 3, 43, 159, 1, 1, 162, 48, None, '2', '0', None, 22),
#  ('willite01', 1950, 1, 'BOS', 'AL', 89, 334, 82, 106, 24, 1, 28, 97, 3, 0, 82, 21, None, '0', '0', None, 12),
#  ('willite01', 1951, 1, 'BOS', 'AL', 148, 531, 109, 169, 28, 4, 30, 126, 1, 1, 144, 45, None, '0', '0', None, 10),
#  ('willite01', 1952, 1, 'BOS', 'AL', 6, 10, 2, 4, 0, 1, 1, 3, 0, 0, 2, 2, None, '0', '0', None, 0),
#  ('willite01', 1953, 1, 'BOS', 'AL', 37, 91, 17, 37, 6, 0, 13, 34, 0, 1, 19, 10, None, '0', '0', None, 1),
#  ('willite01', 1954, 1, 'BOS', 'AL', 117, 386, 93, 133, 23, 1, 29, 89, 0, 0, 136, 32, None, '1', '0', '3', 10),
#  ('willite01', 1955, 1, 'BOS', 'AL', 98, 320, 77, 114, 21, 3, 28, 83, 2, 0, 91, 24, '17', '2', '0', '4', 8),
#  ('willite01', 1956, 1, 'BOS', 'AL', 136, 400, 71, 138, 28, 2, 24, 82, 0, 0, 102, 39, '11', '1', '0', '0', 13),
#  ('willite01', 1957, 1, 'BOS', 'AL', 132, 420, 96, 163, 28, 1, 38, 87, 0, 1, 119, 43, '33', '5', '0', '2', 11),
#  ('willite01', 1958, 1, 'BOS', 'AL', 129, 411, 81, 135, 23, 2, 26, 85, 1, 0, 98, 49, '12', '4', '0', '4', 19),
#  ('willite01', 1959, 1, 'BOS', 'AL', 103, 272, 32, 69, 15, 0, 10, 43, 0, 0, 52, 27, '6', '2', '0', '5', 7),
#  ('willite01', 1960, 1, 'BOS', 'AL', 113, 310, 56, 98, 15, 0, 29, 72, 1, 1, 75, 41, '7', '3', '0', '2', 7)]

# %% [markdown]
# - Find a specific year's batting information. The URL would be ```/people/willite01/batting?yearID=1960```
#
#
# - The corresponding query would be something like ... ...

# %%
# %%sql
#
# select * from batting where playerid='willite01' and yearID=1960
# Out:
#  * mysql+pymysql://dbuser:***@localhost
# 1 rows affected.
# [('willite01', 1960, 1, 'BOS', 'AL', 113, 310, 56, 98, 15, 0, 29, 72, 1, 1, 75, 41, '7', '3', '0', '2', 7)]

# %% [markdown]
# - I needed to use a query for the ```yearID``` because it is not part of "identity."

# %% [markdown]
# ## Architecture

# %% [markdown]
# - We previous saw this diagram.
#
# | ![image.png](attachment:image.png)|
# | :---: |
# | __Remember this Diagram? (Sort of UML Class Diagram)__ |

# %% [markdown]
# - Show demo

# %% [markdown]
# | ![image.png](attachment:image.png) |
# | :---: |
# | __End-to-End Flow Sequence Diagram__ |
#
#
# - Conceptually, this is how this flows end-to-end.
#
#
# - The base class ```AbstractDataService``` defines the methods.
#
#
# - ```RDBBaseDataService``` provides the default mapping to/from SQL.
#
#
# - There will be other classes that map the abstraction to:
#     - DynamoDB
#     - MongoDB
#     - Neo4j
#     - ... ...
#
#
# - The application service implements business logic, for example calling external cloud services. We will see an example of verifying addresses, etc. via a cloud service.

# %% [markdown]
# - You have seen how a Python developer would use relational.
#
#
# - Imagine that our microservice were some Ansys product. I could use the APIs from Python.

# %%
import requests

# %%
res = requests.get(
    "http://127.0.0.1:5001/api/students/dff9"
)

if res.status_code == 200:
    s_data = res.json()
else:
    s_data = None

# %%
s_data
# Out:
# {'uni': 'dff9',
#  'last_name': 'Ferguson',
#  'first_name': 'Donald',
#  'email': 'dff@cs.columbia.edu'}

# %% [markdown]
# - Well, that was kind of clunky. I want to make using my "service" more intuitive for Python developers.

# %%
class Student:
    
    _base_url = "http://127.0.0.1:5001/api/students"
    _find_by_uni = "http://127.0.0.1:5001/api/students/{uni}"
    
    def __init__(self, uni=None, last_name=None, first_name=None, email=None):
        self.uni = uni
        self.last_name = last_name
        self.first_name = first_name
        self.email = email
        
    @classmethod
    def find_by_uni(cls, uni):
        
        url = Student._find_by_uni.format(uni=uni)
        res = requests.get(url)
        
        if res.status_code == 200:
            s_data = res.json()
        else:
            s_data = None
            
        if s_data:
            result = Student(s_data['uni'],
                            s_data['last_name'],
                            s_data['first_name'],
                            s_data['email'])
        else:
            result = None
            
        return result

# %%
a_student = Student.find_by_uni('dff9')

# %%
type(a_student)
# Out:
# __main__.Student

# %%
if a_student and a_student.uni == 'dff9':
    print("Don!")
else:
    print("Boring")
# Out:
# Don!

# %% [markdown]
# - The Pervasive Insights focus on APIs has many facets. Two critical ones are ... ...
#     - Generic enablement of calling APIs remotely.
#     - Adapting APIs in a specific language and environments model.
#
#
# - You can see this in other areas. The shallow use of SQL

# %%
conn = pymysql.connect(
    user="dbuser",
    password="dbuserdbuser",
    host = "localhost",
    cursorclass = pymysql.cursors.DictCursor,
    autocommit = True
    )

# %%
cur = conn.cursor()
res = cur.execute("select * from intro_cloud.students where uni=%s", args=("dff9"))
if res >= 1:
    result = cur.fetchall()
else:
    result = None
    
cur.close()

# %%
result
# Out:
# [{'uni': 'dff9',
#   'last_name': 'Ferguson',
#   'first_name': 'Donald',
#   'email': 'dff@cs.columbia.edu'}]

# %%
type(result)
# Out:
# list

# %%
type(result[0])
# Out:
# dict

# %% [markdown]
# - But, Python people think in higher abstractions ... ... Pandas is an example.

# %%
# %%sql batters_1960 <<
#     select distinct playerID, teamID, yearID, ab, h, rbi, hr from lahmansdb.batting where yearID=1960
# Out:
#  * mysql+pymysql://dbuser:***@localhost
# 637 rows affected.
# Returning data to local variable batters_1960

# %%
batters_df = batters_1960.DataFrame()

# %%
batters_df
# Out:
#       playerID teamID  yearID   ab    h  rbi  hr
# 0    aaronha01    ML1    1960  590  172  126  40
# 1    abernte02    WS1    1960    1    1    0   0
# 2    adairje01    BAL    1960    5    1    1   1
# 3    adcocjo01    ML1    1960  514  153   91  25
# 4    aguirha01    DET    1960   28    1    0   0
# ..         ...    ...     ...  ...  ...  ...  ..
# 632  worthal01    CHA    1960    2    2    0   0
# 633  wrighme01    CHN    1960    2    0    0   0
# 634   wynnea01    CHA    1960   75   15    7   1
# 635   yosted01    DET    1960  497  129   47  14
# 636  zimmedo01    CHN    1960  368   95   35   6
#
# [637 rows x 7 columns]

# %%
batters_df['avg'] = batters_df['h']/batters_df['ab']

# %%
batters_df
# Out:
#       playerID teamID  yearID   ab    h  rbi  hr       avg
# 0    aaronha01    ML1    1960  590  172  126  40  0.291525
# 1    abernte02    WS1    1960    1    1    0   0  1.000000
# 2    adairje01    BAL    1960    5    1    1   1  0.200000
# 3    adcocjo01    ML1    1960  514  153   91  25  0.297665
# 4    aguirha01    DET    1960   28    1    0   0  0.035714
# ..         ...    ...     ...  ...  ...  ...  ..       ...
# 632  worthal01    CHA    1960    2    2    0   0  1.000000
# 633  wrighme01    CHN    1960    2    0    0   0  0.000000
# 634   wynnea01    CHA    1960   75   15    7   1  0.200000
# 635   yosted01    DET    1960  497  129   47  14  0.259557
# 636  zimmedo01    CHN    1960  368   95   35   6  0.258152
#
# [637 rows x 8 columns]

# %%
bos_batters = batters_df[batters_df['teamID'] == 'BOS']

# %%
bos_batters
# Out:
#       playerID teamID  yearID   ab    h  rbi  hr       avg
# 54   boonera01    BOS    1960   78   16   11   1  0.205128
# 55   borlato01    BOS    1960   13    0    0   0  0.000000
# 58   bowsfte01    BOS    1960    4    1    2   0  0.250000
# 67   breweto01    BOS    1960   62   12    2   1  0.193548
# 85   buddido01    BOS    1960  428  105   36   6  0.245327
# 93   busbyji01    BOS    1960    0    0    0   0       NaN
# 107  casalje01    BOS    1960   33    9    4   0  0.272727
# 117  chittne01    BOS    1960    1    0    0   0  0.000000
# 126  clintlo01    BOS    1960  298   68   37   6  0.228188
# 136  coughma01    BOS    1960   19    3    0   0  0.157895
# 156  delocik01    BOS    1960   43    5    0   0  0.116279
# 173  earlear01    BOS    1960    1    0    0   0  0.000000
# 193  fornimi01    BOS    1960   15    6    1   0  0.400000
# 210  geigega01    BOS    1960  245   74   33   9  0.302041
# 219   giledo01    BOS    1960   51    9    4   1  0.176471
# 240  greenpu01    BOS    1960  260   63   21   3  0.242308
# 255  hardyca01    BOS    1960  145   34   15   2  0.234483
# 269  hillmda01    BOS    1960    6    0    0   0  0.000000
# 282  jacksro01    BOS    1960   31    7    0   0  0.225806
# 304  keougma01    BOS    1960  105   26    9   1  0.247619
# 365  malzofr01    BOS    1960  595  161   79  14  0.270588
# 404  monbobi01    BOS    1960   65    6    1   0  0.092308
# 417  muffebi01    BOS    1960   41   11    3   0  0.268293
# 429  nichoch02    BOS    1960    3    0    0   0  0.000000
# 433  nixonru01    BOS    1960  272   81   33   5  0.297794
# 447  pagliji01    BOS    1960   62   19    9   2  0.306452
# 482  repulri01    BOS    1960  136   33   20   3  0.242647
# 499  runnepe01    BOS    1960  528  169   35   2  0.320076
# 504  sadowed01    BOS    1960   93   20    8   3  0.215054
# 549  stalltr01    BOS    1960    0    0    0   0       NaN
# 550  stephge01    BOS    1960  109   25   11   2  0.229358
# 560  sturdto01    BOS    1960   22    4    1   0  0.181818
# 561  sullifr01    BOS    1960   40    5    2   0  0.125000
# 562  sulliha02    BOS    1960  124   20   10   3  0.161290
# 566  tasbywi01    BOS    1960  385  108   37   7  0.280519
# 577  thomsbo01    BOS    1960  114   30   20   5  0.263158
# 604  webstra01    BOS    1960    3    0    1   0  0.000000
# 605  wertzvi01    BOS    1960  443  125  103  19  0.282167
# 618  willite01    BOS    1960  310   98   72  29  0.316129
# 620  willste01    BOS    1960    8    2    1   0  0.250000
# 621  wilsoea01    BOS    1960   23    4    2   0  0.173913
# 631  worthal01    BOS    1960    1    0    0   0  0.000000

# %% [markdown]
# - How will some of this come together ... ...
#
# | ![image.png](attachment:image.png) |
# | :---: |
# | __Enablement Concept for Python__ |
